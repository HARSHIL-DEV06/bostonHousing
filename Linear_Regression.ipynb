# %%
# https://youtu.be/MJ1vWb1rGwM?si=is01TFHHruqu4SmY

# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
"""%matplotlib inline is a magic command used in Jupyter Notebooks. It tells the notebook to display Matplotlib plots directly
 inside the notebook cells, right below the code that generates them, instead of opening them in a separate window."""
# Out:
# '%matplotlib inline is a magic command used in Jupyter Notebooks. It tells the notebook to display Matplotlib plots directly\n inside the notebook cells, right below the code that generates them, instead of opening them in a separate window.'

# %%
#load the dataset of house pricing dataset direct from sklearn
# The load_boston dataset has been removed from scikit-learn due to ethical concerns.
# Using fetch_california_housing as an alternative.
from sklearn.datasets import fetch_california_housing
df = fetch_california_housing()

# %%
type(df)
# Out:
# sklearn.utils._bunch.Bunch

# %%
df
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]], shape=(20640, 8)),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894], shape=(20640,)),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
# ...

# %%
df.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
df.values()
# Out:
# dict_values([array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
#check description of the dataset
print(df)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
print(df.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# ...

# %%
print(df.data)
# Out:
# [[   8.3252       41.            6.98412698 ...    2.55555556
#     37.88       -122.23      ]
#  [   8.3014       21.            6.23813708 ...    2.10984183
#     37.86       -122.22      ]
#  [   7.2574       52.            8.28813559 ...    2.80225989
#     37.85       -122.24      ]
#  ...
#  [   1.7          17.            5.20554273 ...    2.3256351
#     39.43       -121.22      ]
#  [   1.8672       18.            5.32951289 ...    2.12320917
#     39.43       -121.32      ]
#  [   2.3886       16.            5.25471698 ...    2.61698113
#     39.37       -121.24      ]]

# %%
#the df object is a scikit-learn Bunch object, not a Pandas DataFrame. Bunch objects do not have an .info() method. To fix this, I will convert the data into a Pandas DataFrame and then use .info() to get a summary of the DataFrame.
df_housing = pd.DataFrame(df.data, columns=df.feature_names)
df_housing['MedHouseVal'] = df.target
df_housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %% [markdown]
# # **Preparing the dataset**

# %%
df_housing = pd.DataFrame(df.data, columns=df.feature_names)
df_housing['MedHouseVal'] = df.target
df_housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
df_housing.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
#check missing value
df_housing.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %%
# Check Statstic
df_housing.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
#Exploratory Data Analysis
#Corelation
df_housing.corr()
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge    -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms     0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms   -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population   0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup     0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude    -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude   -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# MedHouseVal  0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#              Latitude  Longitude  MedHouseVal
# MedInc      -0.079809  -0.015176     0.688075
# HouseAge     0.011173  -0.108197     0.105623
# AveRooms     0.106389  -0.027540     0.151948
# ...

# %%
"""Strong positive correlations बताते हैं कि variables साथ‑साथ बढ़ते हैं (income और house value).

Strong negative correlations बताते हैं कि एक बढ़े तो दूसरा घटता है (latitude और longitude).

Near zero correlations का मतलब है variables का कोई खास संबंध नहीं (population और house value)."""
# Out:
# 'Strong positive correlations बताते हैं कि variables साथ‑साथ बढ़ते हैं (income और house value).\n\nStrong negative correlations बताते हैं कि एक बढ़े तो दूसरा घटता है (latitude और longitude).\n\nNear zero correlations का मतलब है variables का कोई खास संबंध नहीं (population और house value).'

# %%
plt.scatter(df_housing['MedInc'], df_housing['MedHouseVal'])
plt.xlabel('MedInc')
plt.ylabel('MedHouseVal')
#
# Out:
# Text(0, 0.5, 'MedHouseVal')

# %%
import seaborn as sns
sns.regplot(x=df_housing['AveBedrms'],y=df_housing['MedInc'],data=df_housing)
# Out:
# <Axes: xlabel='AveBedrms', ylabel='MedInc'>

# %%
#dependent and independent feature
df_housing
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
X=df_housing.iloc[:,:-1]
y=df_housing.iloc[:,-1]

# %%
X.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
y.head()
# Out:
# 0    4.526
# 1    3.585
# 2    3.521
# 3    3.413
# 4    3.422
# Name: MedHouseVal, dtype: float64

# %% [markdown]
# **Train Test Split**

# %%
from sklearn.model_selection import  train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 7061   4.1312      35.0  5.882353   0.975490      1218.0  2.985294     33.93
# 14689  2.8631      20.0  4.401210   1.076613       999.0  2.014113     32.79
# 17323  4.2026      24.0  5.617544   0.989474       731.0  2.564912     34.59
# 10056  3.1094      14.0  5.869565   1.094203       302.0  2.188406     39.26
# 15750  3.3068      52.0  4.801205   1.066265      1526.0  2.298193     37.77
# ...       ...       ...       ...        ...         ...       ...       ...
# 11284  6.3700      35.0  6.129032   0.926267       658.0  3.032258     33.78
# 11964  3.0500      33.0  6.868597   1.269488      1753.0  3.904232     34.02
# 5390   2.9344      36.0  3.986717   1.079696      1756.0  3.332068     34.03
# 860    5.7192      15.0  6.395349   1.067979      1777.0  3.178891     37.58
# 15795  2.5755      52.0  3.402576   1.058776      2619.0  2.108696     37.77
#
#        Longitude
# 7061     -118.02
# ...

# %%
X_test
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20046  1.6812      25.0  4.192201   1.022284      1392.0  3.877437     36.06
# 3024   2.5313      30.0  5.039384   1.193493      1565.0  2.679795     35.14
# 15663  3.4801      52.0  3.977155   1.185877      1310.0  1.360332     37.80
# 20484  5.7376      17.0  6.163636   1.020202      1705.0  3.444444     34.28
# 9814   3.7250      34.0  5.492991   1.028037      1063.0  2.483645     36.62
# ...       ...       ...       ...        ...         ...       ...       ...
# 17505  2.9545      47.0  4.195833   1.020833       581.0  2.420833     37.36
# 13512  1.4891      41.0  4.551852   1.118519       994.0  3.681481     34.11
# 10842  3.5120      16.0  3.762287   1.075614      5014.0  2.369565     33.67
# 16559  3.6500      10.0  5.502092   1.060371      5935.0  3.547519     37.82
# 5786   3.0520      17.0  3.355781   1.019695      4116.0  2.614994     34.15
#
#        Longitude
# 20046    -119.01
# ...

# %% [markdown]
# **Standardize  the dataset**

# %%
#because all the feature calculating in differnt unit so we try to keep all feature in same backet
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
import pickle
pickle.dump(scaler,open('scaling.pkl','wb'))

# %%
X_train
# Out:
# array([[ 0.13350629,  0.50935748,  0.18106017, ..., -0.01082519,
#         -0.80568191,  0.78093406],
#        [-0.53221805, -0.67987313, -0.42262953, ..., -0.08931585,
#         -1.33947268,  1.24526986],
#        [ 0.1709897 , -0.36274497,  0.07312833, ..., -0.04480037,
#         -0.49664515, -0.27755183],
#        ...,
#        [-0.49478713,  0.58863952, -0.59156984, ...,  0.01720102,
#         -0.75885816,  0.60119118],
#        [ 0.96717102, -1.07628333,  0.39014889, ...,  0.00482125,
#          0.90338501, -1.18625198],
#        [-0.68320166,  1.85715216, -0.82965604, ..., -0.0816717 ,
#          0.99235014, -1.41592345]], shape=(14448, 8))

# %% [markdown]
# **Model Trainning**

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(reg.coef_)
# Out:
# [ 8.49221760e-01  1.22119309e-01 -2.99558449e-01  3.48409673e-01
#  -8.84488134e-04 -4.16980388e-02 -8.93855649e-01 -8.68616688e-01]

# %%
print(reg.intercept_)
# Out:
# 2.06923960894241

# %%
reg.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'positive': False,
#  'tol': 1e-06}

# %%
reg_pred = reg.predict(X_test_scaled)

# %%
reg_pred
# Out:
# array([0.72604907, 1.76743383, 2.71092161, ..., 2.07465531, 1.57371395,
#        1.82744133], shape=(6192,))

# %%
plt.scatter(y_test,reg_pred)

# %%
#residuals (Error)
residuals = y_test - reg_pred

# %%
residuals
# Out:
# 20046   -0.249049
# 3024    -1.309434
# 15663    2.289088
# 20484   -0.649147
# 9814     0.173042
#            ...
# 17505    0.155059
# 13512   -0.237516
# 10842    0.109345
# 16559   -0.379714
# 5786     0.270559
# Name: MedHouseVal, Length: 6192, dtype: float64

# %%
#plot errors into the graph
sns.displot(residuals,kind="kde")

# %%
plt.scatter(reg_pred,residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
# Out:
# 0.5272474538305951
# 0.5305677824766752

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# R2 Score

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.5957702326061665

# %%
#Display adjusted R2 score
1- (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.5952472117200027

# %%
temp =df.data[0].reshape(1,-1)

# %%
reg.predict(temp)
# Out:
# array([84.33102212])

# %%
# tranforme the data
scaler.transform(temp)
# Out:
# c:\Users\Hp\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[ 2.33526315,  0.98504972,  0.63012521, -0.16586931, -0.96995366,
#         -0.04555657,  1.04385626, -1.32105914]])

# %%
reg.predict(scaler.transform(temp))
# Out:
# c:\Users\Hp\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([4.14333441])

# %% [markdown]
# Pickling the model file for deployment

# %%
import pickle
pickle.dump(reg,open('regmodel.pkl','wb'))

# %%
pickle_model = pickle.load(open('regmodel.pkl','rb'))

# %%
pickle_model.predict(scaler.transform(df.data[0].reshape(1,-1)))
# Out:
# c:\Users\Hp\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([4.14333441])
